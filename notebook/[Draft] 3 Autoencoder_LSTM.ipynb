# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from tensorflow.keras import layers, losses
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from sklearn.preprocessing import StandardScaler

import seaborn as sns
from matplotlib import rcParams

import warnings
warnings.filterwarnings('ignore')

# %%
def plot_loss_accuracy(history):
    rcParams['figure.figsize'] = 20,3
    fig, ax = plt.subplots(1,2)
    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])
    ax[0].title.set_text('model loss')
    ax.flat[0].set(ylabel = 'loss',xlabel='epoch')
    ax[0].legend(['train', 'val'], loc='upper right')

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    ax[1].plot(history.history['accuracy'])
    ax[1].plot(history.history['val_accuracy'])
    ax[0].title.set_text('model accuracy')
    ax.flat[1].set(ylabel = 'accuracy',xlabel='epoch')
    ax[1].legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
def load_data(path='../data/'):
    df_sensors = pd.read_csv(path + 'PdM_telemetry.csv')
    df_metadata = pd.read_csv(path + 'PdM_machines.csv')
    df_maintenance = pd.read_csv(path + 'PdM_maint.csv')
    df_failures = pd.read_csv(path + 'PdM_failures.csv')
    df_errors = pd.read_csv(path + 'PdM_errors.csv')
    return df_sensors, df_metadata, df_maintenance, df_failures, df_errors

# %%
df_sensors, df_metadata, df_maintenance, df_failures, df_errors = load_data()

# %%
# Format date & time. Sort based on date for better readability
tables = [df_sensors, df_maintenance, df_failures, df_errors]
for df in tables:
    df["datetime"] = pd.to_datetime(df["datetime"], format="%Y-%m-%d %H:%M:%S")
    df.sort_values(["datetime", "machineID"], inplace=True, ignore_index=True)

# %%
base_features = list(df_sensors.drop(['datetime', 'machineID'], axis=1).columns)

# %%
machine_id = 10
time_step = 24

# %%
df = df_sensors.merge(df_failures, how='left').merge(df_errors, how='left').query('machineID == @machine_id').reset_index(drop=True)
# df = df_sensors.merge(df_failures, how='left').merge(df_errors, how='left').merge(df_metadata, how='left').query('model == "model3"').reset_index(drop=True)
df = df.replace('NaN', np.nan)
df['is_error'] = ~((df['errorID'].isnull()))
# df['is_anomaly'] = ~((df['failure'].isnull()))
#Iterar sobre las filas donde 'anomaly' es 1
df['is_anomaly'] = False
for idx in df[~(df['failure'].isnull())].index:
    # Marcar las 24 filas anteriores como anomalías
    start_idx = max(0, idx - time_step)  # Asegurarse de no salir del rango del DataFrame
    df.loc[start_idx:idx, 'is_anomaly'] = True

# %%
def create_sequences(values: list) -> np.array:
    output = []
    for i in range(len(values) - time_step + 1):
        output.append(values[i : (i + time_step)])
    return np.stack(output)

# %%
scaler_auto = StandardScaler() 
scaler_auto.fit(df.drop(['machineID', 'datetime','failure', 'errorID','is_anomaly','is_error'], axis=1))
# Out:
# StandardScaler()

# %%
def transform_values(dataframe, scaler):
    dataframe = dataframe.reset_index(drop=True)
    np_scaled = scaler_auto.transform(dataframe.drop(['machineID', 'datetime','failure', 'errorID','is_anomaly','is_error'], axis=1))
    # np_scaled = np.hstack((np_scaled, dataframe['model'].to_numpy().reshape((dataframe['model'].shape[0]),1)))
    data = create_sequences(np_scaled)
    labels = dataframe.loc[time_step-1:,'is_anomaly'].astype('int').values
    return data, labels

# %%
data_list = []
labels_list = []
for key,data_group in df.groupby('machineID', group_keys=False):
    data, labels = transform_values(data_group, scaler=scaler_auto)
    data_list.append(data)
    labels_list.append(labels)
data = np.concatenate(data_list)
labels = np.concatenate(labels_list)

# %%
print(data.shape)
print(labels.shape)
# Out:
# (8742, 24, 4)
# (8742,)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size = 0.2, random_state = 21)

# %%
train_labels = train_labels.astype(bool)
test_labels = test_labels.astype(bool)

#Normal data
# n_train_data = train_data[~train_labels]
# n_test_data = test_data[~test_labels]

# #Abnormal data
# an_train_data = train_data[train_labels]
# an_test_data = test_data[test_labels]

# %%
class detector(Model):
  def __init__(self):
    super(detector, self).__init__()
    self.encoder = tf.keras.Sequential([
                                        layers.LSTM(128, activation='relu', return_sequences=True),
                                        layers.LSTM(64, activation='relu', return_sequences=False),
                                        # layers.LSTM(32, activation='relu', return_sequences=True),
                                        # layers.LSTM(8, activation='relu', return_sequences=False),
                                        layers.Dropout(rate=0.2),
                                        layers.RepeatVector(data.shape[1])
    ])
    self.decoder = tf.keras.Sequential([
                                        layers.LSTM(64, activation='relu', return_sequences=True),
                                        layers.LSTM(128, activation='relu', return_sequences=True),
                                        # layers.LSTM(32, activation='relu', return_sequences=True),
                                        # layers.LSTM(64, activation='relu', return_sequences=True),
                                        layers.Dropout(rate=0.2),
                                        layers.TimeDistributed(layers.Dense(data.shape[2])),
    ])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)
#Compiling Model
autoencoder = detector()
autoencoder.compile(optimizer='adam', loss='mse', metrics=["accuracy"])
history = autoencoder.fit(train_data, train_data, epochs = 500, batch_size=512, validation_data=(test_data, test_data), callbacks=[callback])
# autoencoder.fit(n_train_data, n_train_data, epochs = 150, batch_size=512, validation_data=(n_test_data, n_test_data))
# Out:
# Epoch 1/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 271ms/step - accuracy: 0.3075 - loss: 0.9936 - val_accuracy: 0.3249 - val_loss: 0.9303
# Epoch 2/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 0.3333 - loss: 0.9249 - val_accuracy: 0.3495 - val_loss: 0.8973
# Epoch 3/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 259ms/step - accuracy: 0.3497 - loss: 0.9011 - val_accuracy: 0.3553 - val_loss: 0.8883
# Epoch 4/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.3540 - loss: 0.8922 - val_accuracy: 0.3576 - val_loss: 0.8836
# Epoch 5/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 288ms/step - accuracy: 0.3583 - loss: 0.8857 - val_accuracy: 0.3617 - val_loss: 0.8803
# Epoch 6/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.3608 - loss: 0.8861 - val_accuracy: 0.3627 - val_loss: 0.8834
# Epoch 7/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.3611 - loss: 0.8874 - val_accuracy: 0.3662 - val_loss: 0.8752
# Epoch 8/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.3662 - loss: 0.8800 - val_accuracy: 0.3568 - val_loss: 0.8847
# Epoch 9/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 293ms/step - accuracy: 0.3614 - loss: 0.8837 - val_accuracy: 0.3753 - val_loss: 0.8661
# Epoch 10/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 294ms/step - accuracy: 0.3760 - loss: 0.8678 - val_accuracy: 0.3849 - val_loss: 0.8545
# Epoch 11/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 296ms/step - accuracy: 0.3858 - loss: 0.8574 - val_accuracy: 0.3889 - val_loss: 0.8470
# Epoch 12/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.3865 - loss: 0.8498 - val_accuracy: 0.3933 - val_loss: 0.8410
# Epoch 13/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.3916 - loss: 0.8485 - val_accuracy: 0.3946 - val_loss: 0.8380
# Epoch 14/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.3936 - loss: 0.8418 - val_accuracy: 0.3934 - val_loss: 0.8364
# Epoch 15/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - accuracy: 0.3948 - loss: 0.8394 - val_accuracy: 0.3945 - val_loss: 0.8357
# Epoch 16/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.3978 - loss: 0.8361 - val_accuracy: 0.3977 - val_loss: 0.8314
# Epoch 17/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - accuracy: 0.3988 - loss: 0.8336 - val_accuracy: 0.3987 - val_loss: 0.8295
# Epoch 18/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step - accuracy: 0.3990 - loss: 0.8334 - val_accuracy: 0.3989 - val_loss: 0.8287
# Epoch 19/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.4005 - loss: 0.8306 - val_accuracy: 0.4017 - val_loss: 0.8222
# Epoch 20/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 0.4037 - loss: 0.8290 - val_accuracy: 0.4015 - val_loss: 0.8284
# Epoch 21/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.4007 - loss: 0.8274 - val_accuracy: 0.4061 - val_loss: 0.8168
# Epoch 22/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 282ms/step - accuracy: 0.4051 - loss: 0.8191 - val_accuracy: 0.3995 - val_loss: 0.8315
# Epoch 23/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.4056 - loss: 0.8277 - val_accuracy: 0.4096 - val_loss: 0.8120
# Epoch 24/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - accuracy: 0.4121 - loss: 0.8186 - val_accuracy: 0.4128 - val_loss: 0.8106
# Epoch 25/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 0.4098 - loss: 0.8133 - val_accuracy: 0.4143 - val_loss: 0.8102
# Epoch 26/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 285ms/step - accuracy: 0.4135 - loss: 0.8099 - val_accuracy: 0.4172 - val_loss: 0.7995
# Epoch 27/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 289ms/step - accuracy: 0.4169 - loss: 0.8046 - val_accuracy: 0.4200 - val_loss: 0.7966
# Epoch 28/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.4200 - loss: 0.8014 - val_accuracy: 0.4178 - val_loss: 0.8011
# Epoch 29/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 303ms/step - accuracy: 0.4187 - loss: 0.8032 - val_accuracy: 0.4205 - val_loss: 0.7949
# Epoch 30/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - accuracy: 0.4207 - loss: 0.8007 - val_accuracy: 0.4214 - val_loss: 0.7924
# Epoch 31/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 289ms/step - accuracy: 0.4224 - loss: 0.7992 - val_accuracy: 0.4191 - val_loss: 0.7970
# Epoch 32/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.4183 - loss: 0.8029 - val_accuracy: 0.4230 - val_loss: 0.7906
# Epoch 33/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 286ms/step - accuracy: 0.4199 - loss: 0.7952 - val_accuracy: 0.4238 - val_loss: 0.7884
# Epoch 34/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step - accuracy: 0.4249 - loss: 0.7920 - val_accuracy: 0.4215 - val_loss: 0.7878
# Epoch 35/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.4201 - loss: 0.7954 - val_accuracy: 0.4239 - val_loss: 0.7883
# Epoch 36/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 265ms/step - accuracy: 0.4191 - loss: 0.7952 - val_accuracy: 0.4240 - val_loss: 0.7878
# Epoch 37/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.4237 - loss: 0.7918 - val_accuracy: 0.4260 - val_loss: 0.7800
# Epoch 38/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 294ms/step - accuracy: 0.4262 - loss: 0.7874 - val_accuracy: 0.4297 - val_loss: 0.7794
# Epoch 39/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - accuracy: 0.4265 - loss: 0.7856 - val_accuracy: 0.4276 - val_loss: 0.7868
# Epoch 40/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 300ms/step - accuracy: 0.4283 - loss: 0.7892 - val_accuracy: 0.4337 - val_loss: 0.7753
# Epoch 41/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 0.4336 - loss: 0.7781 - val_accuracy: 0.4353 - val_loss: 0.7707
# Epoch 42/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 290ms/step - accuracy: 0.4331 - loss: 0.7750 - val_accuracy: 0.4343 - val_loss: 0.7689
# Epoch 43/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 272ms/step - accuracy: 0.4322 - loss: 0.7731 - val_accuracy: 0.4345 - val_loss: 0.7679
# Epoch 44/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.4353 - loss: 0.7735 - val_accuracy: 0.4383 - val_loss: 0.7644
# Epoch 45/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.4356 - loss: 0.7742 - val_accuracy: 0.4383 - val_loss: 0.7656
# Epoch 46/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.4403 - loss: 0.7709 - val_accuracy: 0.4396 - val_loss: 0.7620
# Epoch 47/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 0.4423 - loss: 0.7634 - val_accuracy: 0.4403 - val_loss: 0.7585
# Epoch 48/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 285ms/step - accuracy: 0.4425 - loss: 0.7646 - val_accuracy: 0.4437 - val_loss: 0.7569
# Epoch 49/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 301ms/step - accuracy: 0.4386 - loss: 0.7625 - val_accuracy: 0.4425 - val_loss: 0.7557
# Epoch 50/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - accuracy: 0.4432 - loss: 0.7629 - val_accuracy: 0.4435 - val_loss: 0.7552
# Epoch 51/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 292ms/step - accuracy: 0.4411 - loss: 0.7596 - val_accuracy: 0.4418 - val_loss: 0.7581
# Epoch 52/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 290ms/step - accuracy: 0.4465 - loss: 0.7603 - val_accuracy: 0.4473 - val_loss: 0.7510
# Epoch 53/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step - accuracy: 0.4466 - loss: 0.7534 - val_accuracy: 0.4489 - val_loss: 0.7541
# Epoch 54/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.4452 - loss: 0.7581 - val_accuracy: 0.4414 - val_loss: 0.7567
# Epoch 55/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 302ms/step - accuracy: 0.4451 - loss: 0.7579 - val_accuracy: 0.4475 - val_loss: 0.7483
# Epoch 56/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 299ms/step - accuracy: 0.4486 - loss: 0.7519 - val_accuracy: 0.4517 - val_loss: 0.7430
# Epoch 57/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 302ms/step - accuracy: 0.4496 - loss: 0.7478 - val_accuracy: 0.4498 - val_loss: 0.7456
# Epoch 58/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.4513 - loss: 0.7441 - val_accuracy: 0.4560 - val_loss: 0.7365
# Epoch 59/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - accuracy: 0.4508 - loss: 0.7436 - val_accuracy: 0.4418 - val_loss: 0.7630
# Epoch 60/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - accuracy: 0.4355 - loss: 0.7704 - val_accuracy: 0.4498 - val_loss: 0.7444
# Epoch 61/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step - accuracy: 0.4478 - loss: 0.7477 - val_accuracy: 0.4563 - val_loss: 0.7345
# Epoch 62/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 296ms/step - accuracy: 0.4560 - loss: 0.7382 - val_accuracy: 0.4596 - val_loss: 0.7278
# Epoch 63/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 288ms/step - accuracy: 0.4575 - loss: 0.7369 - val_accuracy: 0.4569 - val_loss: 0.7439
# Epoch 64/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.4556 - loss: 0.7449 - val_accuracy: 0.4548 - val_loss: 0.7332
# Epoch 65/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step - accuracy: 0.4579 - loss: 0.7349 - val_accuracy: 0.4594 - val_loss: 0.7256
# Epoch 66/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step - accuracy: 0.4601 - loss: 0.7297 - val_accuracy: 0.4622 - val_loss: 0.7219
# Epoch 67/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 272ms/step - accuracy: 0.4636 - loss: 0.7262 - val_accuracy: 0.4464 - val_loss: 0.7472
# Epoch 68/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - accuracy: 0.4521 - loss: 0.7387 - val_accuracy: 0.4577 - val_loss: 0.7318
# Epoch 69/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.4614 - loss: 0.7299 - val_accuracy: 0.4626 - val_loss: 0.7232
# Epoch 70/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - accuracy: 0.4627 - loss: 0.7243 - val_accuracy: 0.4671 - val_loss: 0.7184
# Epoch 71/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 0.4662 - loss: 0.7229 - val_accuracy: 0.4668 - val_loss: 0.7150
# Epoch 72/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.4683 - loss: 0.7189 - val_accuracy: 0.4684 - val_loss: 0.7145
# Epoch 73/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.4576 - loss: 0.7312 - val_accuracy: 0.4521 - val_loss: 0.7374
# Epoch 74/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - accuracy: 0.4573 - loss: 0.7318 - val_accuracy: 0.4648 - val_loss: 0.7184
# Epoch 75/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 286ms/step - accuracy: 0.4663 - loss: 0.7179 - val_accuracy: 0.4701 - val_loss: 0.7117
# Epoch 76/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.4673 - loss: 0.7143 - val_accuracy: 0.4705 - val_loss: 0.7096
# Epoch 77/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 0.4657 - loss: 0.7183 - val_accuracy: 0.4710 - val_loss: 0.7147
# Epoch 78/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - accuracy: 0.4672 - loss: 0.7169 - val_accuracy: 0.4665 - val_loss: 0.7179
# Epoch 79/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.4696 - loss: 0.7156 - val_accuracy: 0.4728 - val_loss: 0.7064
# Epoch 80/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 287ms/step - accuracy: 0.4719 - loss: 0.7118 - val_accuracy: 0.4692 - val_loss: 0.7078
# Epoch 81/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 272ms/step - accuracy: 0.4703 - loss: 0.7087 - val_accuracy: 0.4753 - val_loss: 0.7030
# Epoch 82/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.4751 - loss: 0.7067 - val_accuracy: 0.4663 - val_loss: 0.7139
# Epoch 83/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 282ms/step - accuracy: 0.4647 - loss: 0.7153 - val_accuracy: 0.4727 - val_loss: 0.7041
# Epoch 84/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 0.4759 - loss: 0.7040 - val_accuracy: 0.4768 - val_loss: 0.6974
# Epoch 85/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.4768 - loss: 0.7009 - val_accuracy: 0.4692 - val_loss: 0.7059
# Epoch 86/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.4716 - loss: 0.7089 - val_accuracy: 0.4487 - val_loss: 0.7411
# Epoch 87/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.4568 - loss: 0.7379 - val_accuracy: 0.4666 - val_loss: 0.7142
# Epoch 88/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 313ms/step - accuracy: 0.4701 - loss: 0.7115 - val_accuracy: 0.4796 - val_loss: 0.6988
# Epoch 89/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.4769 - loss: 0.6981 - val_accuracy: 0.4787 - val_loss: 0.6926
# Epoch 90/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.4796 - loss: 0.6960 - val_accuracy: 0.4766 - val_loss: 0.6965
# Epoch 91/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - accuracy: 0.4778 - loss: 0.6980 - val_accuracy: 0.4803 - val_loss: 0.6900
# Epoch 92/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - accuracy: 0.4801 - loss: 0.6887 - val_accuracy: 0.4814 - val_loss: 0.6911
# Epoch 93/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.4817 - loss: 0.6962 - val_accuracy: 0.4806 - val_loss: 0.6882
# Epoch 94/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 275ms/step - accuracy: 0.4827 - loss: 0.6896 - val_accuracy: 0.4821 - val_loss: 0.6887
# Epoch 95/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - accuracy: 0.4819 - loss: 0.6896 - val_accuracy: 0.4844 - val_loss: 0.6845
# Epoch 96/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - accuracy: 0.4839 - loss: 0.6840 - val_accuracy: 0.4873 - val_loss: 0.6798
# Epoch 97/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 0.4844 - loss: 0.6824 - val_accuracy: 0.4839 - val_loss: 0.6852
# Epoch 98/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - accuracy: 0.4802 - loss: 0.6930 - val_accuracy: 0.4786 - val_loss: 0.6910
# Epoch 99/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.4803 - loss: 0.6885 - val_accuracy: 0.4843 - val_loss: 0.6827
# Epoch 100/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.4873 - loss: 0.6827 - val_accuracy: 0.4885 - val_loss: 0.6787
# Epoch 101/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - accuracy: 0.4884 - loss: 0.6784 - val_accuracy: 0.4807 - val_loss: 0.6833
# Epoch 102/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step - accuracy: 0.4875 - loss: 0.6822 - val_accuracy: 0.4919 - val_loss: 0.6744
# Epoch 103/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.4887 - loss: 0.6763 - val_accuracy: 0.4905 - val_loss: 0.6762
# Epoch 104/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.4889 - loss: 0.6770 - val_accuracy: 0.4888 - val_loss: 0.6726
# Epoch 105/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.4923 - loss: 0.6725 - val_accuracy: 0.4924 - val_loss: 0.6688
# Epoch 106/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.4895 - loss: 0.6715 - val_accuracy: 0.4797 - val_loss: 0.6999
# Epoch 107/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 0.4704 - loss: 0.7209 - val_accuracy: 0.4737 - val_loss: 0.7012
# Epoch 108/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.4794 - loss: 0.6939 - val_accuracy: 0.4889 - val_loss: 0.6751
# Epoch 109/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 286ms/step - accuracy: 0.4895 - loss: 0.6723 - val_accuracy: 0.4915 - val_loss: 0.6664
# Epoch 110/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.4952 - loss: 0.6664 - val_accuracy: 0.4948 - val_loss: 0.6645
# Epoch 111/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 257ms/step - accuracy: 0.4945 - loss: 0.6655 - val_accuracy: 0.4865 - val_loss: 0.6719
# Epoch 112/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 0.4934 - loss: 0.6711 - val_accuracy: 0.4947 - val_loss: 0.6677
# Epoch 113/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 0.4957 - loss: 0.6648 - val_accuracy: 0.4937 - val_loss: 0.6622
# Epoch 114/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.4977 - loss: 0.6625 - val_accuracy: 0.4965 - val_loss: 0.6599
# Epoch 115/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.4967 - loss: 0.6598 - val_accuracy: 0.4963 - val_loss: 0.6602
# Epoch 116/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 259ms/step - accuracy: 0.4969 - loss: 0.6644 - val_accuracy: 0.4944 - val_loss: 0.6643
# Epoch 117/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.4954 - loss: 0.6654 - val_accuracy: 0.4979 - val_loss: 0.6587
# Epoch 118/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.5007 - loss: 0.6563 - val_accuracy: 0.4964 - val_loss: 0.6582
# Epoch 119/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 308ms/step - accuracy: 0.4970 - loss: 0.6632 - val_accuracy: 0.4998 - val_loss: 0.6541
# Epoch 120/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.5026 - loss: 0.6546 - val_accuracy: 0.4989 - val_loss: 0.6515
# Epoch 121/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.4973 - loss: 0.6582 - val_accuracy: 0.4953 - val_loss: 0.6599
# Epoch 122/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 282ms/step - accuracy: 0.4996 - loss: 0.6572 - val_accuracy: 0.4993 - val_loss: 0.6527
# Epoch 123/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.5006 - loss: 0.6560 - val_accuracy: 0.4980 - val_loss: 0.6561
# Epoch 124/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 265ms/step - accuracy: 0.5020 - loss: 0.6520 - val_accuracy: 0.5037 - val_loss: 0.6481
# Epoch 125/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.5029 - loss: 0.6503 - val_accuracy: 0.5010 - val_loss: 0.6566
# Epoch 126/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.4885 - loss: 0.6799 - val_accuracy: 0.4488 - val_loss: 0.7498
# Epoch 127/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - accuracy: 0.4570 - loss: 0.7412 - val_accuracy: 0.4697 - val_loss: 0.7103
# Epoch 128/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 272ms/step - accuracy: 0.4762 - loss: 0.7036 - val_accuracy: 0.4831 - val_loss: 0.6840
# Epoch 129/500
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - accuracy: 0.4868 - loss: 0.6790 - val_accuracy: 0.4929 - val_loss: 0.6661

# %%
plot_loss_accuracy(history)

# %%
# reconstructed = autoencoder(n_train_data)
# train_loss = losses.mae(reconstructed, n_train_data)
# # t = np.mean(train_loss) + np.std(train_loss)
# t = np.mean(train_loss) + (5 * np.std(train_loss))
# print(t)

# %%
def result_autoencoder(model: object, x_train: np.array) -> tf.Tensor:
    # Calculate the reconstruction error for each data point
    reconstructions_deep = model.predict(x_train)
    mse = tf.reduce_mean(tf.square(x_train - reconstructions_deep), axis=[1, 2])
    return mse

# %%
mse = result_autoencoder(autoencoder, data)
anomaly_deep_scores = pd.Series(mse.numpy(), name="anomaly_scores")
# Out:
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step

# %%
threshold = anomaly_deep_scores.quantile(0.985)

# %%
# anomalous_deep = anomaly_deep_scores > threshold

# %%
df.loc[time_step-1:,'anomaly_score'] = anomaly_deep_scores.to_numpy()

# %%
df['pred_anomaly'] = False
df.loc[df['anomaly_score'] > threshold,'pred_anomaly'] = True

# %%
import seaborn as sns
from matplotlib import rcParams

# %%
def plot_values(df, base_features):
    rcParams['figure.figsize'] = 20,3
    # for feature in base_features:
    feature='vibration'
    sns.lineplot(df, x='datetime', y=feature)
    sns.scatterplot(df[df['pred_anomaly'] == True], x='datetime', y=feature, color='red', label='Prediction', zorder=7)
    # for error_date in df.loc[df['pred_anomaly'] == True, 'datetime']:
    #     plt.axvline(x=error_date, color='orange', linestyle='--', linewidth=1, label='Error')
    for error_date in df.loc[df['is_anomaly'] == True, 'datetime']:
        plt.axvline(x=error_date, color='red', linestyle='--', linewidth=1, label='Error', alpha=0.05)
    for error_date in df.loc[df['is_error'] == True, 'datetime']:
        plt.axvline(x=error_date, color='orange', linestyle='--', linewidth=1, label='Possible Error', alpha=0.5)
    plt.show()

# %%
machine_id = np.random.choice(df.machineID.unique())
# machine_id = 10
print('ID:',machine_id)
df_tmp = df.query('machineID == @machine_id')
plot_values(df_tmp, base_features=base_features)
# Out:
# ID: 10

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


accuracy = accuracy_score(df['is_anomaly'], df['pred_anomaly'])
print(f'Accuracy: {accuracy:.2f}')
precision = precision_score(df['is_anomaly'], df['pred_anomaly'])
print(f'Precision: {precision:.2f}')
f1 = f1_score(df['is_anomaly'], df['pred_anomaly'])
print(f'F1 Score (Balance between false positives and true positives): {f1:.2f}')

recall = recall_score(df['is_anomaly'], df['pred_anomaly'])
print(f'Recall (How well anomalies are detected - True positives): {recall:.2f}')
# Out:
# Accuracy: 0.97
# Precision: 0.06
# F1 Score (Balance between false positives and true positives): 0.06
# Recall (How well anomalies are detected - True positives): 0.06
